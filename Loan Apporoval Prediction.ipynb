# %% [markdown]
# # Project - Loan Apporoval Prediction

# %% [markdown]
# # Problem Statement
# This dataset is commonly used in machine learning and data analysis to develop models
# and algorithms that predict the likelihood of loan approval based on the given features.

# %%
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# To avoid warning
import warnings
warnings.filterwarnings("ignore")

# Preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler

from scipy.stats import skew

# %%
data=pd.read_csv("loan_approval_dataset.csv")
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0         29900000          12           778                    2400000
# 1         12200000           8           417                    2700000
# 2         29700000          20           506                    7100000
# 3         30700000           8           467                   18200000
# 4         24200000          20           382                   12400000
# ...            ...         ...           ...                        ...
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                     17600000              22700000            8000000
# 1                      2200000               8800000            3300000
# 2                      4500000              33300000           12800000
# 3                      3300000              23300000            7900000
# 4                      8200000              29400000            5000000
# ...                        ...                   ...                ...
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 0        Approved
# 1        Rejected
# 2        Rejected
# 3        Rejected
# 4        Rejected
# ...           ...
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved
#
# [4269 rows x 13 columns]

# %%
data.shape
# Out:
# (4269, 13)

# %%
data.isna().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
data.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()    #remove any leading or trailing whitespace from the column names

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df1 = data.drop(["loan_id"],axis=1)

# %%
df1.describe()
# Out:
#        no_of_dependents  income_annum   loan_amount    loan_term  cibil_score  \
# count       4269.000000  4.269000e+03  4.269000e+03  4269.000000  4269.000000
# mean           2.498712  5.059124e+06  1.513345e+07    10.900445   599.936051
# std            1.695910  2.806840e+06  9.043363e+06     5.709187   172.430401
# min            0.000000  2.000000e+05  3.000000e+05     2.000000   300.000000
# 25%            1.000000  2.700000e+06  7.700000e+06     6.000000   453.000000
# 50%            3.000000  5.100000e+06  1.450000e+07    10.000000   600.000000
# 75%            4.000000  7.500000e+06  2.150000e+07    16.000000   748.000000
# max            5.000000  9.900000e+06  3.950000e+07    20.000000   900.000000
#
#        residential_assets_value  commercial_assets_value  luxury_assets_value  \
# count              4.269000e+03             4.269000e+03         4.269000e+03
# mean               7.472617e+06             4.973155e+06         1.512631e+07
# std                6.503637e+06             4.388966e+06         9.103754e+06
# min               -1.000000e+05             0.000000e+00         3.000000e+05
# 25%                2.200000e+06             1.300000e+06         7.500000e+06
# 50%                5.600000e+06             3.700000e+06         1.460000e+07
# 75%                1.130000e+07             7.600000e+06         2.170000e+07
# max                2.910000e+07             1.940000e+07         3.920000e+07
#
#        bank_asset_value
# count      4.269000e+03
# mean       4.976692e+06
# std        3.250185e+06
# min        0.000000e+00
# 25%        2.300000e+06
# 50%        4.600000e+06
# 75%        7.100000e+06
# max        1.470000e+07

# %%
df1.duplicated().sum()  #giving the total count of duplicate rows.
# Out:
# 0

# %%
w=df1.columns
w
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
df1.nunique()
# Out:
# no_of_dependents              6
# education                     2
# self_employed                 2
# income_annum                 98
# loan_amount                 378
# loan_term                    10
# cibil_score                 601
# residential_assets_value    278
# commercial_assets_value     188
# luxury_assets_value         379
# bank_asset_value            146
# loan_status                   2
# dtype: int64

# %%
for i in w:
    print(data[i].value_counts())
    print("*"*100)
# Out:
# no_of_dependents
# 4    752
# 3    727
# 0    712
# 2    708
# 1    697
# 5    673
# Name: count, dtype: int64
# ****************************************************************************************************
# education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64
# ****************************************************************************************************
# self_employed
# Yes    2150
# No     2119
# Name: count, dtype: int64
# ****************************************************************************************************
# income_annum
# 7000000    62
# 4100000    59
# 7600000    57
# 4700000    56
# 6900000    55
#            ..
# 3600000    33
# 3400000    33
# 9300000    33
# 8500000    32
# 6700000    30
# Name: count, Length: 98, dtype: int64
# ****************************************************************************************************
# loan_amount
# 10600000    27
# 20000000    24
# 9400000     24
# 16800000    23
# 23900000    23
#             ..
# 35800000     1
# 38500000     1
# 39500000     1
# 38800000     1
# 36100000     1
# Name: count, Length: 378, dtype: int64
# ****************************************************************************************************
# loan_term
# 6     490
# 12    456
# 4     447
# 10    436
# 18    422
# 16    412
# 20    411
# 14    405
# 2     404
# 8     386
# Name: count, dtype: int64
# ****************************************************************************************************
# cibil_score
# 348    16
# 543    15
# 538    15
# 778    14
# 509    14
#        ..
# 334     2
# 773     2
# 893     2
# 484     2
# 864     1
# Name: count, Length: 601, dtype: int64
# ****************************************************************************************************
# residential_assets_value
# 400000      66
# 500000      63
# 100000      60
# 1000000     57
# 600000      56
#             ..
# 25700000     1
# 20300000     1
# 28300000     1
# 26800000     1
# 27300000     1
# Name: count, Length: 278, dtype: int64
# ****************************************************************************************************
# commercial_assets_value
# 0           107
# 200000      101
# 100000      100
# 300000       90
# 500000       83
#            ...
# 19400000      1
# 18300000      1
# 17400000      1
# 15700000      1
# 18900000      1
# Name: count, Length: 188, dtype: int64
# ****************************************************************************************************
# luxury_assets_value
# 6200000     26
# 2900000     26
# 20400000    26
# 12300000    24
# 12000000    24
#             ..
# 39100000     1
# 37700000     1
# 39200000     1
# 34300000     1
# 36700000     1
# Name: count, Length: 379, dtype: int64
# ****************************************************************************************************
# bank_asset_value
# 1400000     63
# 4900000     63
# 3600000     63
# 4500000     61
# 1600000     60
#             ..
# 14600000     2
# 14200000     2
# 14400000     1
# 14300000     1
# 13700000     1
# Name: count, Length: 146, dtype: int64
# ****************************************************************************************************
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64
# ****************************************************************************************************

# %%
df_obj=df1.select_dtypes(include='object')
df_obj
# Out:
#           education self_employed loan_status
# 0          Graduate            No    Approved
# 1      Not Graduate           Yes    Rejected
# 2          Graduate            No    Rejected
# 3          Graduate            No    Rejected
# 4      Not Graduate           Yes    Rejected
# ...             ...           ...         ...
# 4264       Graduate           Yes    Rejected
# 4265   Not Graduate           Yes    Approved
# 4266   Not Graduate            No    Rejected
# 4267   Not Graduate            No    Approved
# 4268       Graduate            No    Approved
#
# [4269 rows x 3 columns]

# %%
df_num=df1.select_dtypes(exclude='object')
df_num
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                      2400000                 17600000             22700000
# 1                      2700000                  2200000              8800000
# 2                      7100000                  4500000             33300000
# 3                     18200000                  3300000             23300000
# 4                     12400000                  8200000             29400000
# ...                        ...                      ...                  ...
# 4264                   2800000                   500000              3300000
# 4265                   4200000                  2900000             11000000
# 4266                   1200000                 12400000             18100000
# 4267                   8200000                   700000             14100000
# 4268                  17800000                 11800000             35700000
#
#       bank_asset_value
# 0              8000000
# 1              3300000
# 2             12800000
# 3              7900000
# 4              5000000
# ...                ...
# 4264            800000
# 4265           1900000
# 4266           7300000
# 4267           5800000
# 4268          12000000
#
# [4269 rows x 9 columns]

# %%
a=df_num.columns
a
# Out:
# Index(['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term',
#        'cibil_score', 'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value'],
#       dtype='object')

# %% [markdown]
# # Data visualizations

# %%
sns.countplot(x="loan_status",data=data, palette='viridis')
plt.show()

# %%
target_percentage = data['loan_status'].value_counts(normalize=True) * 100
target_percentage
# Out:
# loan_status
# Approved    62.215976
# Rejected    37.784024
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 5))
target_percentage.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Target Column Distribution in Percentage', fontsize=14)
plt.ylabel('Percentage', fontsize=12)
plt.xlabel('loan_status', fontsize=12)
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# # Handling Outliers

# %%
for i in a:
    plt.boxplot(x=df1[i])
    plt.title(i)
    plt.show()

# %%
q1=df1['residential_assets_value'].quantile(0.25)
q3=df1['residential_assets_value'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1", q1)
print("q3", q3)
print("iqr", iqr)
print("upperbound", ub)
print("lowerbound", lb)
# Out:
# q1 2200000.0
# q3 11300000.0
# iqr 9100000.0
# upperbound 24950000.0
# lowerbound -11450000.0

# %%
df1.loc[df1['residential_assets_value']>ub]
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 82                   2   Not Graduate           Yes       9900000
# 98                   4       Graduate            No       9400000
# 123                  0   Not Graduate           Yes       9000000
# 228                  1   Not Graduate           Yes       8700000
# 262                  3       Graduate            No       9200000
# 693                  0       Graduate            No       9200000
# 714                  4   Not Graduate            No       9900000
# 781                  3   Not Graduate           Yes       9900000
# 892                  4       Graduate            No       9300000
# 905                  5   Not Graduate            No       9700000
# 919                  0   Not Graduate           Yes       8800000
# 924                  0   Not Graduate           Yes       8600000
# 953                  5       Graduate           Yes       8700000
# 956                  0   Not Graduate           Yes       9100000
# 987                  5       Graduate            No       9400000
# 997                  3   Not Graduate           Yes       8500000
# 1002                 5   Not Graduate            No       9600000
# 1397                 1   Not Graduate           Yes       9200000
# 1419                 2       Graduate            No       9100000
# 1468                 3   Not Graduate           Yes       9500000
# 1591                 1       Graduate            No       9500000
# 1625                 2   Not Graduate           Yes       9900000
# 1965                 0   Not Graduate            No       9900000
# 1997                 0       Graduate            No       9300000
# 2185                 2       Graduate           Yes       9200000
# 2318                 2   Not Graduate           Yes       9600000
# 2384                 3       Graduate           Yes       9100000
# 2412                 4   Not Graduate            No       9700000
# 2586                 1   Not Graduate           Yes       9800000
# 2715                 4       Graduate           Yes       9100000
# 2818                 1   Not Graduate           Yes       9500000
# 2828                 4       Graduate           Yes       9200000
# 2922                 0   Not Graduate           Yes       9600000
# 2927                 4       Graduate            No       9400000
# 2930                 3   Not Graduate            No       8700000
# 2940                 1       Graduate           Yes       9600000
# 3119                 4   Not Graduate            No       9800000
# 3157                 0   Not Graduate           Yes       8600000
# 3234                 1   Not Graduate            No       9900000
# 3310                 5   Not Graduate            No       8500000
# 3498                 2       Graduate           Yes       9100000
# 3631                 3       Graduate            No       9800000
# 3763                 3       Graduate            No       9600000
# 3782                 5       Graduate           Yes       9500000
# 3860                 4       Graduate            No       8700000
# 3868                 5   Not Graduate            No       9600000
# 3872                 0       Graduate            No       8800000
# 3880                 3   Not Graduate            No       9100000
# 4027                 1   Not Graduate            No       9100000
# 4042                 4       Graduate            No       9300000
# 4074                 4   Not Graduate           Yes       9400000
# 4237                 0   Not Graduate            No       9100000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 82       21200000         16          363                  25500000
# 98       29400000         12          562                  25900000
# 123      18700000         18          865                  26800000
# 228      27000000         10          717                  25500000
# 262      34300000         18          523                  25600000
# 693      25400000          2          783                  25400000
# 714      22700000         12          567                  28300000
# 781      20400000          4          865                  26300000
# 892      24900000         14          455                  27600000
# 905      37000000         14          459                  28700000
# 919      25600000         10          715                  25300000
# 924      23600000          2          361                  25800000
# 953      28100000         10          660                  25500000
# 956      22000000         12          387                  25300000
# 987      25800000         14          625                  28200000
# 997      28300000          2          810                  25200000
# 1002     20700000         14          442                  25800000
# 1397     24500000          4          545                  25700000
# 1419     21700000         12          549                  25500000
# 1468     25500000         12          881                  27000000
# 1591     23000000         10          627                  28500000
# 1625     33200000          4          465                  26300000
# 1965     22300000         20          613                  28400000
# 1997     20300000         14          759                  27000000
# 2185     25300000          4          827                  25900000
# 2318     29800000         16          499                  28500000
# 2384     30100000         14          564                  26600000
# 2412     26200000          4          518                  26200000
# 2586     36000000         12          629                  28000000
# 2715     28400000         12          808                  25800000
# 2818     24400000         14          696                  25500000
# 2828     18600000          2          889                  26900000
# 2922     23800000         12          389                  25200000
# 2927     32200000          6          898                  27600000
# 2930     24800000         20          360                  25300000
# 2940     34100000         20          828                  26100000
# 3119     29400000          8          592                  29100000
# 3157     20000000         10          704                  25400000
# 3234     23400000         16          687                  28200000
# 3310     23400000         16          604                  25100000
# 3498     24200000         16          685                  25600000
# 3631     21000000         12          342                  25400000
# 3763     34500000         20          523                  26100000
# 3782     21700000         16          307                  27500000
# 3860     25200000         18          790                  25000000
# 3868     27100000          8          594                  25500000
# 3872     17500000          4          848                  25400000
# 3880     19300000         12          696                  26200000
# 4027     24000000         20          353                  25100000
# 4042     34900000          6          837                  27400000
# 4074     25700000         14          845                  27300000
# 4237     30100000          8          322                  26200000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 82                   11400000             26600000           6800000
# 98                   15200000             36400000           7100000
# 123                         0             20900000          11300000
# 228                   8600000             17500000           9100000
# 262                   4000000             29100000           8800000
# 693                   2000000             19600000          12400000
# 714                   9900000             29700000           5400000
# 781                   3600000             36500000          12800000
# 892                   4700000             35100000          13900000
# 905                  17900000             22800000           5600000
# 919                   2500000             34900000           8600000
# 924                   5300000             24700000           7500000
# 953                    800000             25900000          10100000
# 956                  15600000             31700000           7000000
# 987                  15400000             30800000          11100000
# 997                   4300000             18500000          10700000
# 1002                  9800000             31800000           8200000
# 1397                        0             20600000          13300000
# 1419                 11000000             34700000          12200000
# 1468                 14100000             21600000           8900000
# 1591                 11500000             21700000           9100000
# 1625                 17000000             24400000           5000000
# 1965                  8900000             23600000           4900000
# 1997                 11600000             26500000          10900000
# 2185                 15900000             19300000          11000000
# 2318                  6300000             31800000           7400000
# 2384                  7300000             22700000           8200000
# 2412                        0             22500000          14000000
# 2586                  4100000             29800000          11200000
# 2715                 11800000             19300000           9700000
# 2818                  6700000             29500000           6300000
# 2828                  4200000             33300000           9700000
# 2922                 15800000             27000000           8300000
# 2927                 11800000             19500000           8600000
# 2930                  8700000             31100000           4300000
# 2940                 19000000             20800000          12400000
# 3119                 16700000             35900000           9000000
# 3157                 10000000             30800000          10300000
# 3234                  3700000             29600000           8200000
# 3310                 16500000             24500000           4800000
# 3498                  1900000             31100000           9100000
# 3631                 16600000             26900000           7000000
# 3763                  2600000             24300000           5300000
# 3782                  2700000             28500000           9700000
# 3860                  9100000             18400000           8400000
# 3868                  4600000             26800000          13300000
# 3872                  8200000             31600000           5100000
# 3880                  7700000             30100000          13300000
# 4027                  9200000             26100000          10900000
# 4042                   800000             21400000           8500000
# 4074                  4100000             26500000          12200000
# 4237                  9500000             18800000           5900000
#
#      loan_status
# 82      Rejected
# 98      Approved
# 123     Approved
# 228     Approved
# 262     Rejected
# 693     Approved
# 714     Approved
# 781     Approved
# 892     Rejected
# 905     Rejected
# 919     Approved
# 924     Rejected
# 953     Approved
# 956     Rejected
# 987     Approved
# 997     Approved
# 1002    Rejected
# 1397    Rejected
# 1419    Rejected
# 1468    Approved
# 1591    Approved
# 1625    Approved
# 1965    Approved
# 1997    Approved
# 2185    Approved
# 2318    Rejected
# 2384    Approved
# 2412    Rejected
# 2586    Approved
# 2715    Approved
# 2818    Approved
# 2828    Approved
# 2922    Rejected
# 2927    Approved
# 2930    Rejected
# 2940    Approved
# 3119    Approved
# 3157    Approved
# 3234    Approved
# 3310    Approved
# 3498    Approved
# 3631    Rejected
# 3763    Rejected
# 3782    Rejected
# 3860    Approved
# 3868    Approved
# 3872    Approved
# 3880    Approved
# 4027    Rejected
# 4042    Approved
# 4074    Approved
# 4237    Rejected

# %%
df1.loc[df1['residential_assets_value']>ub, 'residential_assets_value']=ub

# %%
df1.loc[df1['residential_assets_value']>ub]
# Out:
# Empty DataFrame
# Columns: [no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %%
q1=df1['commercial_assets_value'].quantile(0.25)
q3=df1['commercial_assets_value'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1", q1)
print("q3", q3)
print("iqr", iqr)
print("upperbound", ub)
print("lowerbound", lb)
# Out:
# q1 1300000.0
# q3 7600000.0
# iqr 6300000.0
# upperbound 17050000.0
# lowerbound -8150000.0

# %%
df1.loc[df1['commercial_assets_value']>ub]
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 157                  5   Not Graduate           Yes       9900000
# 231                  2       Graduate            No       9800000
# 258                  0       Graduate            No       9800000
# 323                  3   Not Graduate           Yes       9500000
# 367                  1   Not Graduate           Yes       9400000
# 554                  3   Not Graduate           Yes       9500000
# 791                  4       Graduate           Yes       9300000
# 895                  0       Graduate            No       9400000
# 905                  5   Not Graduate            No       9700000
# 1029                 2   Not Graduate           Yes       9500000
# 1131                 0   Not Graduate            No       9900000
# 1194                 4   Not Graduate           Yes       9000000
# 1254                 5   Not Graduate           Yes       9800000
# 1272                 5   Not Graduate            No       9900000
# 1304                 2       Graduate           Yes       9400000
# 1609                 5   Not Graduate           Yes       9800000
# 1761                 2   Not Graduate           Yes       9800000
# 1768                 4   Not Graduate            No       9900000
# 1812                 5   Not Graduate            No       9000000
# 2004                 2   Not Graduate            No       9900000
# 2302                 5       Graduate           Yes       9700000
# 2349                 0       Graduate            No       9200000
# 2914                 3   Not Graduate           Yes       9900000
# 2933                 0       Graduate            No       9600000
# 2940                 1       Graduate           Yes       9600000
# 2976                 3   Not Graduate           Yes       9400000
# 3000                 1   Not Graduate           Yes       9900000
# 3439                 5   Not Graduate           Yes       9700000
# 3541                 3   Not Graduate            No       8800000
# 3790                 1   Not Graduate            No       9600000
# 3827                 1       Graduate           Yes       9600000
# 3882                 1       Graduate           Yes       9700000
# 3949                 1   Not Graduate           Yes       9100000
# 4010                 3       Graduate           Yes       9000000
# 4120                 3       Graduate            No       9100000
# 4205                 2   Not Graduate            No       8900000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# 157      33300000          6          364                   5300000
# 231      32400000          2          543                  24200000
# 258      38800000          8          652                  23200000
# 323      24200000          8          879                   3100000
# 367      29800000         10          377                  24100000
# 554      22800000          6          319                    200000
# 791      35500000          6          547                   2800000
# 895      27900000          6          456                  21400000
# 905      37000000         14          459                  24950000
# 1029     37000000          8          887                  21800000
# 1131     27000000         16          566                   3500000
# 1194     21500000         14          508                  16600000
# 1254     35700000         10          726                   9400000
# 1272     35800000         20          470                   9500000
# 1304     24800000         14          513                  24200000
# 1609     23200000         10          416                  11000000
# 1761     32700000          2          304                   4700000
# 1768     29100000         18          772                  24100000
# 1812     35200000          2          437                  18400000
# 2004     31600000         16          892                   4200000
# 2302     30100000         12          434                  19600000
# 2349     22500000         10          317                  14200000
# 2914     36500000         16          562                  17300000
# 2933     23200000         18          389                   1000000
# 2940     34100000         20          828                  24950000
# 2976     30900000         20          873                  22800000
# 3000     25700000          2          340                  15600000
# 3439     27400000          2          328                         0
# 3541     24900000         16          668                  16700000
# 3790     32400000         20          447                  15400000
# 3827     35900000          8          534                  24500000
# 3882     34300000         20          756                  15700000
# 3949     23600000         20          535                   2800000
# 4010     18600000         16          518                  18400000
# 4120     19900000          2          711                   2200000
# 4205     17800000         20          603                   3300000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 157                  18700000             27800000           8300000
# 231                  17500000             25700000           7700000
# 258                  19000000             29700000           5400000
# 323                  17200000             26400000          12700000
# 367                  18500000             30900000          11700000
# 554                  18800000             34100000           9400000
# 791                  17800000             27000000          13900000
# 895                  18500000             35600000           7800000
# 905                  17900000             22800000           5600000
# 1029                 18300000             19200000          11700000
# 1131                 17300000             36900000          11500000
# 1194                 17300000             24300000          13100000
# 1254                 18900000             31200000          12000000
# 1272                 18400000             39100000          14700000
# 1304                 18200000             37200000           7500000
# 1609                 17300000             21600000           8500000
# 1761                 19000000             24500000           8600000
# 1768                 19400000             26800000          11700000
# 1812                 17800000             18300000          10400000
# 2004                 17500000             31400000          12700000
# 2302                 17900000             21000000           6900000
# 2349                 17400000             28500000          10700000
# 2914                 18500000             22300000           9800000
# 2933                 17600000             22200000           8800000
# 2940                 19000000             20800000          12400000
# 2976                 17700000             19300000           9000000
# 3000                 18800000             29500000          11800000
# 3439                 18400000             22000000           7900000
# 3541                 17200000             30000000          10500000
# 3790                 18400000             19800000           4700000
# 3827                 17700000             31900000           5400000
# 3882                 18500000             26800000          14100000
# 3949                 17600000             26400000           4500000
# 4010                 17600000             28900000          10300000
# 4120                 17900000             24300000          13000000
# 4205                 17600000             29000000          13100000
#
#      loan_status
# 0       Approved
# 157     Rejected
# 231     Approved
# 258     Approved
# 323     Approved
# 367     Rejected
# 554     Rejected
# 791     Rejected
# 895     Rejected
# 905     Rejected
# 1029    Approved
# 1131    Approved
# 1194    Rejected
# 1254    Approved
# 1272    Rejected
# 1304    Rejected
# 1609    Rejected
# 1761    Approved
# 1768    Approved
# 1812    Approved
# 2004    Approved
# 2302    Rejected
# 2349    Rejected
# 2914    Approved
# 2933    Rejected
# 2940    Approved
# 2976    Approved
# 3000    Rejected
# 3439    Rejected
# 3541    Approved
# 3790    Rejected
# 3827    Rejected
# 3882    Approved
# 3949    Rejected
# 4010    Rejected
# 4120    Approved
# 4205    Approved

# %%
df1.loc[df1['commercial_assets_value']>ub, 'commercial_assets_value']=ub

# %%
df1.loc[df1['commercial_assets_value']>ub]
# Out:
# Empty DataFrame
# Columns: [no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %%
q1=df1['bank_asset_value'].quantile(0.25)
q3=df1['bank_asset_value'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1", q1)
print("q3", q3)
print("iqr", iqr)
print("upperbound", ub)
print("lowerbound", lb)
# Out:
# q1 2300000.0
# q3 7100000.0
# iqr 4800000.0
# upperbound 14300000.0
# lowerbound -4900000.0

# %%
df1.loc[df1['bank_asset_value']>ub]
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 200                  4   Not Graduate           Yes       9800000
# 1272                 5   Not Graduate            No       9900000
# 1633                 0       Graduate           Yes       9800000
# 1674                 1   Not Graduate            No       9800000
# 1805                 5   Not Graduate            No       9900000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 200      21200000         20          355                  22000000
# 1272     35800000         20          470                   9500000
# 1633     23200000         10          573                  23900000
# 1674     21300000          2          356                  23000000
# 1805     33600000         20          580                   7000000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 200                   8900000             31800000          14400000
# 1272                 17050000             39100000          14700000
# 1633                  3300000             23600000          14600000
# 1674                 12300000             25700000          14600000
# 1805                 10800000             37400000          14700000
#
#      loan_status
# 200     Rejected
# 1272    Rejected
# 1633    Approved
# 1674    Rejected
# 1805    Approved

# %%
df1.loc[df1['bank_asset_value']>ub,'bank_asset_value']=ub

# %%
df1.loc[df1['bank_asset_value']>ub]
# Out:
# Empty DataFrame
# Columns: [no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %%
for i in a:
    plt.boxplot(x=df1[i])
    plt.title(i)
    plt.show()

# %%
for i in df_obj:
    print(df1[i].value_counts().sort_index())
    print("*"*50)
# Out:
# education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64
# **************************************************
# self_employed
# No     2119
# Yes    2150
# Name: count, dtype: int64
# **************************************************
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64
# **************************************************

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df1['education']=le.fit_transform(df1['education'])
df1['self_employed']=le.fit_transform(df1['self_employed'])
df1['loan_status']=le.fit_transform(df1['loan_status'])

# %%
df1
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          0              0       9600000     29900000
# 1                    0          1              1       4100000     12200000
# 2                    3          0              0       9100000     29700000
# 3                    3          0              0       8200000     30700000
# 4                    5          1              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          0              1       1000000      2300000
# 4265                 0          1              1       3300000     11300000
# 4266                 2          1              0       6500000     23900000
# 4267                 1          1              0       4100000     12800000
# 4268                 1          0              0       9200000     29700000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0            12          778                   2400000
# 1             8          417                   2700000
# 2            20          506                   7100000
# 3             8          467                  18200000
# 4            20          382                  12400000
# ...         ...          ...                       ...
# 4264         12          317                   2800000
# 4265         20          559                   4200000
# 4266         18          457                   1200000
# 4267          8          780                   8200000
# 4268         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17050000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#       loan_status
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 4264            1
# 4265            0
# 4266            1
# 4267            0
# 4268            0
#
# [4269 rows x 12 columns]

# %%
df1["loan_status"].value_counts()
# Out:
# loan_status
# 0    2656
# 1    1613
# Name: count, dtype: int64

# %%
df1.corr().tail(1)
# Out:
#              no_of_dependents  education  self_employed  income_annum  \
# loan_status          0.018114   0.004918      -0.000345      0.015189
#
#              loan_amount  loan_term  cibil_score  residential_assets_value  \
# loan_status     -0.01615   0.113036    -0.770518                  0.014985
#
#              commercial_assets_value  luxury_assets_value  bank_asset_value  \
# loan_status                -0.008799             0.015465          0.006746
#
#              loan_status
# loan_status          1.0

# %%
sns.heatmap(df1.corr().tail(1), cmap="Set1")
plt.show()

# %%
for i in df1:
    print(i,skew(df1[i]))
    print("*"*50)
# Out:
# no_of_dependents -0.017964228035582553
# **************************************************
# education 0.008901470220180877
# **************************************************
# self_employed -0.014523690500055735
# **************************************************
# income_annum -0.012809922048151696
# **************************************************
# loan_amount 0.3086153978159286
# **************************************************
# loan_term 0.03634613066755639
# **************************************************
# cibil_score -0.009036100886026986
# **************************************************
# residential_assets_value 0.9405494883732272
# **************************************************
# commercial_assets_value 0.9283791739208204
# **************************************************
# luxury_assets_value 0.3220942776824955
# **************************************************
# bank_asset_value 0.5586130915667582
# **************************************************
# loan_status 0.5039101304749749
# **************************************************

# %%
x = df1.drop('loan_status', axis= 1)
y = df1['loan_status']

# %% [markdown]
# # Scaling

# %%
w=df1.columns
w
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
scaler=MinMaxScaler()

# %%
for i in w:
    df1[i]=scaler.fit_transform(df1[[i]])

# %%
df1
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                  0.4        0.0            0.0      0.969072     0.755102
# 1                  0.0        1.0            1.0      0.402062     0.303571
# 2                  0.6        0.0            0.0      0.917526     0.750000
# 3                  0.6        0.0            0.0      0.824742     0.775510
# 4                  1.0        1.0            1.0      0.989691     0.609694
# ...                ...        ...            ...           ...          ...
# 4264               1.0        0.0            1.0      0.082474     0.051020
# 4265               0.0        1.0            1.0      0.319588     0.280612
# 4266               0.4        1.0            0.0      0.649485     0.602041
# 4267               0.2        1.0            0.0      0.402062     0.318878
# 4268               0.2        0.0            0.0      0.927835     0.750000
#
#       loan_term  cibil_score  residential_assets_value  \
# 0      0.555556     0.796667                  0.099800
# 1      0.333333     0.195000                  0.111776
# 2      1.000000     0.343333                  0.287425
# 3      0.333333     0.278333                  0.730539
# 4      1.000000     0.136667                  0.499002
# ...         ...          ...                       ...
# 4264   0.555556     0.028333                  0.115768
# 4265   1.000000     0.431667                  0.171657
# 4266   0.888889     0.261667                  0.051896
# 4267   0.333333     0.800000                  0.331337
# 4268   0.444444     0.511667                  0.714571
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    1.000000             0.575835          0.559441
# 1                    0.129032             0.218509          0.230769
# 2                    0.263930             0.848329          0.895105
# 3                    0.193548             0.591260          0.552448
# 4                    0.480938             0.748072          0.349650
# ...                       ...                  ...               ...
# 4264                 0.029326             0.077121          0.055944
# 4265                 0.170088             0.275064          0.132867
# 4266                 0.727273             0.457584          0.510490
# 4267                 0.041056             0.354756          0.405594
# 4268                 0.692082             0.910026          0.839161
#
#       loan_status
# 0             0.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 4264          1.0
# 4265          0.0
# 4266          1.0
# 4267          0.0
# 4268          0.0
#
# [4269 rows x 12 columns]

# %%
from imblearn.over_sampling import SMOTE, RandomOverSampler

# %%
x = df1.drop('loan_status', axis= 1)
y = df1['loan_status']

smt = SMOTE(random_state=10)
x_sample, y_sample = smt.fit_resample(x,y)

x = x_sample
y = y_sample

# %%
y.value_counts()
# Out:
# loan_status
# 0.0    2656
# 1.0    2656
# Name: count, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
X = df1.drop('loan_status',axis=1)
Y = df1['loan_status']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=11)

# %%
X_train
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 1899               0.2        0.0            0.0      0.030928     0.025510
# 1767               1.0        0.0            1.0      0.000000     0.002551
# 2076               0.4        1.0            0.0      0.134021     0.099490
# 2727               0.4        0.0            1.0      0.917526     0.880102
# 2245               0.8        0.0            1.0      0.237113     0.221939
# ...                ...        ...            ...           ...          ...
# 332                0.4        1.0            1.0      0.453608     0.461735
# 1293               0.2        0.0            1.0      0.319588     0.262755
# 4023               0.0        1.0            0.0      0.371134     0.331633
# 3775               0.8        1.0            1.0      0.020619     0.028061
# 1945               0.0        1.0            0.0      0.731959     0.543367
#
#       loan_term  cibil_score  residential_assets_value  \
# 1899   0.222222     0.616667                  0.043912
# 1767   0.888889     0.870000                  0.011976
# 2076   0.777778     0.785000                  0.103792
# 2727   1.000000     0.893333                  0.854291
# 2245   0.444444     0.156667                  0.271457
# ...         ...          ...                       ...
# 332    0.000000     0.425000                  0.311377
# 1293   0.666667     0.736667                  0.015968
# 4023   0.222222     0.591667                  0.387226
# 3775   0.444444     0.608333                  0.015968
# 1945   0.000000     0.298333                  0.718563
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value
# 1899                 0.029326             0.028278          0.048951
# 1767                 0.017595             0.007712          0.020979
# 2076                 0.046921             0.138817          0.076923
# 2727                 0.639296             0.778920          0.692308
# 2245                 0.117302             0.179949          0.209790
# ...                       ...                  ...               ...
# 332                  0.140762             0.357326          0.293706
# 1293                 0.035191             0.208226          0.314685
# 4023                 0.000000             0.213368          0.181818
# 3775                 0.017595             0.030848          0.013986
# 1945                 0.721408             0.401028          0.524476
#
# [3415 rows x 11 columns]

# %%
X_test
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 2801               0.6        0.0            1.0      0.432990     0.247449
# 2834               0.4        1.0            0.0      0.185567     0.102041
# 777                0.4        0.0            0.0      0.422680     0.232143
# 2379               1.0        0.0            0.0      0.731959     0.660714
# 1005               0.4        0.0            0.0      0.783505     0.558673
# ...                ...        ...            ...           ...          ...
# 1919               0.6        1.0            0.0      0.072165     0.040816
# 3133               0.8        0.0            0.0      0.051546     0.051020
# 1167               0.2        0.0            1.0      0.824742     0.479592
# 97                 0.4        1.0            0.0      0.876289     0.630102
# 2828               0.8        0.0            1.0      0.927835     0.466837
#
#       loan_term  cibil_score  residential_assets_value  \
# 2801   0.333333     0.958333                  0.239521
# 2834   0.777778     0.328333                  0.207585
# 777    0.000000     0.308333                  0.443114
# 2379   0.444444     0.751667                  0.059880
# 1005   0.444444     0.725000                  0.391218
# ...         ...          ...                       ...
# 1919   0.555556     0.411667                  0.099800
# 3133   0.777778     0.646667                  0.063872
# 1167   0.333333     0.531667                  0.690619
# 97     1.000000     0.935000                  0.590818
# 2828   0.000000     0.981667                  1.000000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value
# 2801                 0.304985             0.293059          0.286713
# 2834                 0.011730             0.138817          0.195804
# 777                  0.475073             0.275064          0.153846
# 2379                 0.715543             0.678663          0.727273
# 1005                 0.269795             0.583548          0.482517
# ...                       ...                  ...               ...
# 1919                 0.023460             0.069409          0.027972
# 3133                 0.017595             0.041131          0.027972
# 1167                 0.715543             0.802057          0.461538
# 97                   0.498534             0.588689          0.510490
# 2828                 0.246334             0.848329          0.678322
#
# [854 rows x 11 columns]

# %%
X_train.shape
# Out:
# (3415, 11)

# %%
X_test.shape
# Out:
# (854, 11)

# %%
Y_train.shape
# Out:
# (3415,)

# %%
Y_test.shape
# Out:
# (854,)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train,Y_train)
Y_pred = model_LR.predict(X_test)

# %%
# Training Accuracy
y_pred_train= model_LR.predict(X_train)

cnf_matrix = confusion_matrix(y_pred_train, Y_train)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred_train, Y_train)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred_train, Y_train)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[1988  147]
#  [ 128 1152]]
# ************************************************************
# Accuracy :  0.9194729136163983
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94      2135
#          1.0       0.89      0.90      0.89      1280
#
#     accuracy                           0.92      3415
#    macro avg       0.91      0.92      0.91      3415
# weighted avg       0.92      0.92      0.92      3415

# %%
# Testing Accuracy
y_pred = model_LR.predict(X_test)

cnf_matrix = confusion_matrix(y_pred, Y_test)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred, Y_test)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred, Y_test)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[505  42]
#  [ 35 272]]
# ************************************************************
# Accuracy :  0.9098360655737705
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93       547
#          1.0       0.87      0.89      0.88       307
#
#     accuracy                           0.91       854
#    macro avg       0.90      0.90      0.90       854
# weighted avg       0.91      0.91      0.91       854

# %% [markdown]
# # AUC-ROC Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
y_pred_prob = model_LR.predict_proba(X_train)
y_pred_prob[:,1]
fpr, tpr , thresh = roc_curve(Y_train, y_pred_prob[:,1])

# %%
plt.plot(fpr, tpr)

plt.xlabel("False positive rate (FRP) --->")
plt.ylabel("True positive rate (TRP) --->") 
plt.title("Approved/Rejected")
# Out:
# Text(0.5, 1.0, 'Approved/Rejected')

# %%
auc_value= auc(fpr, tpr)

# %%
auc_value
# Out:
# 0.9687759669718309

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
model_dt = DecisionTreeClassifier(random_state=11)
model_dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=11)

# %%
# Training Accuracy
y_pred_train= model_dt.predict(X_train)

cnf_matrix = confusion_matrix(y_pred_train, Y_train)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred_train, Y_train)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred_train, Y_train)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[2116    0]
#  [   0 1299]]
# ************************************************************
# Accuracy :  1.0
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2116
#          1.0       1.00      1.00      1.00      1299
#
#     accuracy                           1.00      3415
#    macro avg       1.00      1.00      1.00      3415
# weighted avg       1.00      1.00      1.00      3415

# %%
# Testing Accuracy
y_pred = model_dt.predict(X_test)

cnf_matrix = confusion_matrix(y_pred, Y_test)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred, Y_test)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred, Y_test)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[528   9]
#  [ 12 305]]
# ************************************************************
# Accuracy :  0.9754098360655737
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98       537
#          1.0       0.97      0.96      0.97       317
#
#     accuracy                           0.98       854
#    macro avg       0.97      0.97      0.97       854
# weighted avg       0.98      0.98      0.98       854

# %%
plot_tree(model_dt)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(random_state=1)
model_rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Training Accuracy
y_pred_train= model_rf.predict(X_train)

cnf_matrix = confusion_matrix(y_pred_train, Y_train)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred_train, Y_train)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred_train, Y_train)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[2116    0]
#  [   0 1299]]
# ************************************************************
# Accuracy :  1.0
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2116
#          1.0       1.00      1.00      1.00      1299
#
#     accuracy                           1.00      3415
#    macro avg       1.00      1.00      1.00      3415
# weighted avg       1.00      1.00      1.00      3415

# %%
y_pred = model_rf.predict(X_test)

cnf_matrix = confusion_matrix(y_pred, Y_test)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred, Y_test)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred, Y_test)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[531  10]
#  [  9 304]]
# ************************************************************
# Accuracy :  0.977751756440281
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98       541
#          1.0       0.97      0.97      0.97       313
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %% [markdown]
# # Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model_ab = AdaBoostClassifier(random_state=30)
model_ab.fit(X_train, Y_train)
y_pred2 = model_ab.predict(X_test)

# %%
# Training Accuracy
y_pred_train= model_ab.predict(X_train)

cnf_matrix = confusion_matrix(y_pred_train, Y_train)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred_train, Y_train)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred_train, Y_train)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[2069   47]
#  [  47 1252]]
# ************************************************************
# Accuracy :  0.9724743777452416
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      2116
#          1.0       0.96      0.96      0.96      1299
#
#     accuracy                           0.97      3415
#    macro avg       0.97      0.97      0.97      3415
# weighted avg       0.97      0.97      0.97      3415

# %%
# Testing Accuracy
y_pred = model_ab.predict(X_test)

cnf_matrix = confusion_matrix(y_pred, Y_test)
print("Confusion Matrix: \n", cnf_matrix)
print("*"*60)

accuracy = accuracy_score(y_pred, Y_test)
print("Accuracy : ",accuracy)
print("*"*60)

clf_report  = classification_report(y_pred, Y_test)
print("Classification report :\n",clf_report)
# Out:
# Confusion Matrix:
#  [[521  19]
#  [ 19 295]]
# ************************************************************
# Accuracy :  0.955503512880562
# ************************************************************
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96       540
#          1.0       0.94      0.94      0.94       314
#
#     accuracy                           0.96       854
#    macro avg       0.95      0.95      0.95       854
# weighted avg       0.96      0.96      0.96       854

# %%
model_LR.score(X_test,Y_test)
# Out:
# 0.9098360655737705

# %%
model_dt.score(X_test,Y_test)
# Out:
# 0.9754098360655737

# %%
model_rf.score(X_test,Y_test)
# Out:
# 0.977751756440281

# %%
model_ab.score(X_test,Y_test)
# Out:
# 0.955503512880562

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. Loan Status is negatively correlated to Cibil Score. Becuase during Label Encoding, Approved was encoded as 0 and Non approval as 1.
#
# 2. Cibil score has the highest importance score to predict the Loan Status.And other features followed by less significance or impact.

# %% [raw]
# The logistic regression model demonstrated the best performance in predicting loan approval likelihood, achieving high accuracy and robust evaluation metrics.
# Its simplicity, interpretability, and effectiveness in handling the dataset's characteristics make it the most suitable model for this problem.
# This model provides reliable predictions and valuable insights into the factors influencing loan approval decisions.
